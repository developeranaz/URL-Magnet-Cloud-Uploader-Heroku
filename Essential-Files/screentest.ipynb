# %%
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# Image Widget

file = open("Aria2Mega.jpg", "rb")
image = file.read()

image_headline = widgets.Image(
                    value=image,
                    format='jpg',
                    width='400'
                )

label_headline = widgets.Label(
                    #value='Aria2Mega',
                    #style={'description_width': 'large'}
                )

vbox_headline = widgets.VBox([label_headline])

# %%
# magnet/url

name = widgets.Text(placeholder='http://ser.ver.mp4 OR magnet:?xt=ur..annonce' ,flex_flow='column' ,align_items='center')

# %%
# config
username = widgets.Text(
    value='username@gmail.com',
    placeholder='username',
    description='Username:',
    disabled=False
)

# %%
# password
password = widgets.Password(
           value='password',
           placeholder='password',
           description='Password:',
           disabled=False
        )

# %%
# number of threads
threats = widgets.IntSlider(
            value=10, # default value
            min=2, 
            max=12,
            step=1,
           # style='danger'
            style={'description_width': 'initial', 'handle_color': '#f84834'} 
        )

# %%
# button send
from ipywidgets import Button
button_send= Button(description='START UPLOAD',button_style='danger' ,border='solid',width='50%',tooltip='Send')
button_send.layout.align_items = 'center'
output = widgets.Output()

def on_button_clicked(event):
    with output:
        clear_output()
        #rclone version
        # %mkdir /home/d1
        # %cd /home/d1
        # %rm *
        ! rclone config create 'CLOUDNAME' 'mega' 'user' {username.value} 'pass' {password.value}
        ! rclone copy /Essential-Files/d CLOUDNAME:
        ! aria2c -x{threats.value} '{name.value}'
        ! rclone copy --progress --stats-one-line /home/d1 CLOUDNAME:
        # aria2c -x10 {name.value}
        print(f"Your file uploaded to MEGA: {username.value} at {threats.value} x threads")

button_send.on_click(on_button_clicked)

vbox_result = widgets.VBox([button_send, output])

# %%
# stacked right hand side

#text_0 = widgets.HTML(value="<center><h1><u>Aria2Mega</u></h1></center>")
text_1 = widgets.HTML(value="<h4>Thread or Max connection Per download 👇</h4>")
line1 = widgets.HTML(value="<hr>")
btc= widgets.HTML(value="<font color='lime'><h6>DONATE BTC: 1J48LksQNiASuj48nwYATXdFzQSwdrnx7c <br> Developed by developeranaz <br> Issues can be reported here <a> https://github.com/developeranaz/URL-TO-MEGA-HEROKU </a></h6></font>")
text_2= widgets.HTML(value="<h4>Type your MEGA Username and Password here </h4>")
#text_3= widgets.HTML(value="<h4>Type your Mega Password here 👇</h4>")
text_4= widgets.HTML(value="<h4>Paste magnet/direct links here 👇</h4>")
#text_5= widgets.HTML(value="<h4>Click the download button below</h4>")

vbox_text = widgets.VBox([image_headline, line1, text_4, name, line1, text_1, threats, line1, text_2, username, password, line1, vbox_result, btc])

# %%
page = widgets.HBox([vbox_headline, vbox_text])
display(page)
